# %%
import pandas as pd

# %%
df = pd.read_csv('geo.csv', names=('movie_title', 'director', 'genru',  'actor', 'country_of_origin', 'images_url', 'details_url'))

# %%
df
# Out:
#                            movie_title          director  \
# 0                                オデッセイ         リドリー・スコット
# 1                            映画「信長協奏曲」              松山博昭
# 2                            殿、利息でござる！              中村義洋
# 3                     スター・ウォーズ／フォースの覚醒        J.J.エイブラムス
# 4    機動戦士ガンダム THE ORIGIN II 哀しみのアルテイシア              今西隆志
# 5                          ジュラシック・ワールド         コリン・トレボロウ
# 6                               バケモノの子               細田守
# 7                             マイ・インターン        ナンシー・マイヤーズ
# 8                              劇場版MOZU             羽住英一郎
# 9                         レヴェナント：蘇えりし者   アレハンドロ・G・イニャリトゥ
# 10                              デッドプール           ティム・ミラー
# 11                                天空の蜂               堤幸彦
# 12                            僕だけがいない街             平川雄一朗
# 13                           007 スペクター           サム・メンデス
# 14                              アーロと少年          ピーター・ソーン
# ...
